# %% [markdown]
# ## Step 1

# %%
# %sql
Create volume if not exists workspace.default.volume36;

# %%
dbutils.fs.ls("/Volumes/workspace/default/volume36")

# %%
base_path= "/Volumes/workspace/default/volume36"
raw_path= f"{base_path}/raw"
processed_path= f"{base_path}/processed"
archive_path=f"{base_path}/archive"

# %% [markdown]
# ## Step 2

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/Volume36/raw")
dbutils.fs.mkdirs("/Volumes/workspace/default/Volume36/processed")
dbutils.fs.mkdirs("/Volumes/workspace/default/Volume36/archive")

# %% [markdown]
# ## Step 3

# %%
sample_data= """"patient_id,patient_name,age,gender
1,John Doe, 68,M
2,Jane Smith,54,F
3,Michael Johnson,42,M
4,Sophia Lee,38,F
5,David Kim,72,M
"""

# %%
dbutils.fs.put("/Volumes/workspace/default/volume36/raw/healthcare_data.csv",sample_data)

# %% [markdown]
# ## Step 4

# %%
dbutils.fs.ls("/Volumes/workspace/default/volume36/raw/healthcare_data.csv")

# %% [markdown]
# ## Step 5

# %%
dbutils.fs.cp("/Volumes/workspace/default/volume36/raw/healthcare_data.csv", "/Volumes/workspace/default/volume36/processed/sample_health_data.csv")

# %% [markdown]
# ## Step 6

# %%
dbutils.widgets.dropdown(
    "environment_1","dev",["dev","QA","Prod"],"environment_name"
)
dbutils.widgets.text(
    "owner_1","","owner name"
)

# %% [markdown]
# ## Step 7

# %%
environment_2= dbutils.widgets.get("environment_1")
owner_2=dbutils.widgets.get("owner_1")
print("Environment: ", environment_2)
print("Owner: ", owner_2)

# %% [markdown]
# ## Step 8

# %%
dbutils.fs.mv("/Volumes/workspace/default/volume36/processed/sample_health_data.csv","/Volumes/workspace/default/volume36/archive/sheath_data.csv")

# %% [markdown]
# ## Step 9

# %%
dbutils.notebook.run("/Workspace/Repos/Github/Databricks_Usecase2/child_1", 60)

# %% [markdown]
# ## Step 10

# %%
dbutils.notebook.exit("Pipeline completed successfully")
